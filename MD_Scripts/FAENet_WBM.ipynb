# %%
from __future__ import annotations

import pytorch_lightning as pl
from torch import nn
import torch


from ase import Atoms
from matsciml.datasets.transforms import (
    PeriodicPropertiesTransform,
    PointCloudToGraphTransform,
    FrameAveraging,
)
from matsciml.lightning.data_utils import MatSciMLDataModule
from matsciml.models.base import ScalarRegressionTask
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score

# %%
from __future__ import annotations

import os
import sys
import time
import copy
import yaml
import logging
import argparse

import numpy as np
import torch
import pytest

from ase import Atoms, units
from ase.md.langevin import Langevin
from ase.io import read, write
from ase.constraints import FixAtoms
from ase.calculators.calculator import Calculator, all_changes
from ase.stress import full_3x3_to_voigt_6_stress
from ase.calculators.singlepoint import SinglePointCalculator as sp

from tqdm import tqdm
import pytorch_lightning as pl

from matsciml.common.registry import registry
from matsciml.common.utils import radius_graph_pbc, setup_imports, setup_logging
from matsciml.datasets.transforms import (
    PeriodicPropertiesTransform,
    PointCloudToGraphTransform,
    FrameAveraging,
)
from matsciml.datasets.trajectory_lmdb import data_list_collater
from matsciml.lightning import MatSciMLDataModule
from matsciml.models.pyg import FAENet
from matsciml.models.base import ForceRegressionTask
from matsciml.models.utils.io import multitask_from_checkpoint
from matsciml.preprocessing.atoms_to_graphs import *

# %%
from matsciml.models.utils.io import * 
checkpoint_path = "/home/m3rg2000/trained_models/faenet/model_MP.ckpt"
loaded_model = multitask_from_checkpoint(checkpoint_path)
#task.to('cuda')

# %%
norm_factors={
    "corrected_total_energy_mean": -202.79426006491903,
    "corrected_total_energy_std": 205.18613142401196,
    "energy_mean": -202.79426006491903,
    "energy_std": 205.18613142401196
}

# %%
from matsciml.datasets.trajectory_lmdb import data_list_collater
from matsciml.preprocessing.atoms_to_graphs import *
a2g=AtomsToGraphs(max_neigh=200,
            radius=6,
            r_energy=False,
            r_forces=False,
            r_distances=False,
            r_edges=True,
            r_fixed=True,)
f_avg=FrameAveraging(frame_averaging="3D", fa_method="stochastic")

def convAtomstoBatch(atoms):
    data_obj=a2g.convert(atoms)
    Reformatted_batch={
        'cell' : data_obj.cell,
        'natoms' :  torch.Tensor([data_obj.natoms]).unsqueeze(0),
        'edge_index' : [data_obj.edge_index.shape],
        'cell_offsets': data_obj.cell_offsets,
        'y' : None,
        'force' : None, 
        'fixed' : [data_obj.fixed],
        'tags' : None,
        'sid' :None,
        'fid' : None,
        'dataset' : 'S2EFDataset',
        'graph' : data_list_collater([data_obj]),
    }
    Reformatted_batch=f_avg(Reformatted_batch)
    return Reformatted_batch

# %%
# Load Data
dm = MatSciMLDataModule(
    "MaterialsProjectDataset",
    train_path="/home/m3rg2000/matsciml/Scale_new_lmdb/10k_new",#TRAIN_PATH,
    # val_split=VAL_PATH,
    # test_split=VAL_PATH,
    dset_kwargs={
        "transforms": [
            PeriodicPropertiesTransform(cutoff_radius=6.0, adaptive_cutoff=True),
            PointCloudToGraphTransform(
                "pyg",
                node_keys=["pos", "atomic_numbers"],
            ),
            FrameAveraging(frame_averaging="3D", fa_method="stochastic"),
        ],
    },
    batch_size=1,
)

dm.setup()
train_loader = dm.train_dataloader()
dataset_iter = iter(train_loader)
batch = next(dataset_iter)

# %%
from torch_geometric.data import Data, Batch
# def batch2cuda(batch):
#     for key in batch.keys():
#         if type(batch[key])==torch.Tensor:
#             batch[key]=batch[key].to('cuda')
#     batch['graph']=batch['graph'].to('cuda')
def batch2cuda(batch):
    # Recursively move all tensors in nested structures to 'cuda'
    # batch['graph']=batch['graph'].to('cuda')
    if isinstance(batch, dict):
        return {k: batch2cuda(v) for k, v in batch.items()}
    elif isinstance(batch, list):
        return [batch2cuda(v) for v in batch]
    elif isinstance(batch, torch.Tensor):
        return batch.to('cuda')
    elif isinstance(batch, Data) or isinstance(batch, Batch):
        return batch.to('cuda')
    else:
        return batch

# %%
from tqdm import tqdm
# Initialize lists for storing predictions and actual values
def initialize_prediction_lists():
    return {
        'Predictions_corr_e': [],
        'Actuals_corr_e': [],
        'Predictions_e': [],
        'Actuals_e': [],
        'Predictions_Fx': [],
        'Actuals_Fx': [],
        'Predictions_Fy': [],
        'Actuals_Fy': [],
        'Predictions_Fz': [],
        'Actuals_Fz': []
    }

# Function to process a data loader
def process_data_loader(data_loader, norm_factors, task, limit=None):
    results = initialize_prediction_lists()
    counter = 0

    for batch in tqdm(data_loader):
        #batch2cuda(batch)
        Result = task.forward(batch)
        
        Pred_Energy_corr = Result['regression0']['corrected_total_energy'].detach().item() * norm_factors['energy_std'] + norm_factors['energy_mean']
        Pred_Energy = Result['force_regression0']['energy'].detach().item() * norm_factors['energy_std'] + norm_factors['energy_mean']

        Pred_Forces = Result['force_regression0']['force'].detach()* norm_factors['energy_std']
        Actual_Energy_corr = batch['targets']['energy'].item()
        Actual_Energy = batch['targets']['corrected_total_energy'].detach().item()
        
        Actual_Forces = batch['targets']['force'].detach()

        results['Predictions_corr_e'].append(Pred_Energy_corr)
        results['Actuals_corr_e'].append(Actual_Energy_corr)
        
        results['Predictions_e'].append(Pred_Energy)
        results['Actuals_e'].append(Actual_Energy)
        
        results['Predictions_Fx'] += Pred_Forces[:, 0].reshape(-1).detach().cpu().numpy().tolist()
        results['Actuals_Fx'] += Actual_Forces[:, 0].reshape(-1).detach().cpu().numpy().tolist()

        results['Predictions_Fy'] += Pred_Forces[:, 1].reshape(-1).detach().cpu().numpy().tolist()
        results['Actuals_Fy'] += Actual_Forces[:, 1].reshape(-1).detach().cpu().numpy().tolist()

        results['Predictions_Fz'] += Pred_Forces[:, 2].reshape(-1).detach().cpu().numpy().tolist()
        results['Actuals_Fz'] += Actual_Forces[:, 2].reshape(-1).detach().cpu().numpy().tolist()

        counter += 1
        del batch
        if limit and counter >= limit:
            break

    return results

# %%
result=process_data_loader(train_loader, norm_factors, task, limit=10000)
train_results=result
test_results=result
# Out:
#  64%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                               | 6421/10000 [07:25<04:34, 13.04it/s]/home/m3rg2000/miniconda3/envs/matsciml/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:221: UserWarning: No Pauling electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉| 9999/10000 [11:34<00:00, 14.39it/s]

# %%
# Function to plot R² score with train and test data
# Function to plot R² score with train and test data
def plot_r2_score(train_actual, train_pred, test_actual, test_pred, title="Title", suffix="500k_Faenet"):
    save_dir ='/home/m3rg2000/Simulation/plot_workstation/'  # Ensure this path ends with a slash

    # Calculate R² score for train and test data
    r2_train = r2_score(train_actual, train_pred)
    r2_test = r2_score(test_actual, test_pred)

    # Create the scatter plot
    plt.figure(figsize=(6, 6))  # Adjust the figure size as needed
    plt.scatter(train_actual, train_pred, label='Train', color='blue')
    plt.scatter(test_actual, test_pred, label='Test', color='green')
    plt.xlabel("Actual", fontsize=20, fontweight='bold')
    plt.ylabel("Predicted", fontsize=20, fontweight='bold')
    plt.xticks(rotation=90, fontsize=20, fontweight='bold')
    plt.yticks(fontsize=20, fontweight='bold')
    # Plot the 45-degree line
    min_val = min(min(train_actual), min(test_actual), min(train_pred), min(test_pred))
    max_val = max(max(train_actual), max(test_actual), max(train_pred), max(test_pred))
    plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--')
    plt.title(title, fontsize=20, fontweight='bold')

    # Annotate the R² scores on the plot
    plt.text(0.05, 0.95, f'Train R² = {r2_train:.5f}', transform=plt.gca().transAxes, fontsize=12, fontweight='bold', verticalalignment='top', color='blue')
    plt.text(0.05, 0.90, f'Test R² = {r2_test:.5f}', transform=plt.gca().transAxes, fontsize=12, fontweight='bold', verticalalignment='top', color='green')

    # Save the plot to the specified location with the title in the filename
    filename = f"{title.replace(' ', '_')}_{suffix}.png"
    plt.savefig(f'{save_dir}{filename}', bbox_inches='tight')  # Use bbox_inches='tight' to adjust the bounding box

    # Show the plot
    plt.show()
    # Clear the current figure to avoid overlap
    plt.clf()

# %%
# Plot and save the results for combined training and test data
plot_r2_score(train_results['Actuals_corr_e'], train_results['Predictions_corr_e'], test_results['Actuals_corr_e'], test_results['Predictions_corr_e'], "Corrected Total Energy", "10k_Faenet_MP")
plot_r2_score(train_results['Actuals_e'], train_results['Predictions_e'], test_results['Actuals_e'], test_results['Predictions_e'], "Energy", "10k_Faenet_MP")
plot_r2_score(train_results['Actuals_Fx'], train_results['Predictions_Fx'], test_results['Actuals_Fx'], test_results['Predictions_Fx'], "Fx", "10k_Faenet_MP")
plot_r2_score(train_results['Actuals_Fy'], train_results['Predictions_Fy'], test_results['Actuals_Fy'], test_results['Predictions_Fy'], "Fy", "10k_Faenet_MP")
plot_r2_score(train_results['Actuals_Fz'], train_results['Predictions_Fz'], test_results['Actuals_Fz'], test_results['Predictions_Fz'], "Fz", "10k_Faenet_MP")

# %%
import json, bz2
from pymatgen.entries.computed_entries import ComputedStructureEntry

with bz2.open("/home/m3rg2000/matbench-discovery/data/wbm/raw/wbm-cse-step-1.json.bz2") as fh:
  data = json.loads(fh.read().decode('utf-8'))

# %%
def element_to_atomic_number(element_list):
   
    mapping = {'H': 1, 'He': 2, 'Li': 3, 'Be': 4, 'B': 5, 'C': 6, 'N': 7, 'O': 8, 
              'F': 9, 'Ne': 10, 'Na': 11, 'Mg': 12, 'Al': 13, 'Si': 14, 'P': 15, 
              'S': 16, 'Cl': 17, 'Ar': 18, 'K': 19, 'Ca': 20, 'Sc': 21, 'Ti': 22, 
              'V': 23, 'Cr': 24, 'Mn': 25, 'Fe': 26, 'Co': 27, 'Ni': 28, 'Cu': 29, 
              'Zn': 30, 'Ga': 31, 'Ge': 32, 'As': 33, 'Se': 34, 'Br': 35, 'Kr': 36, 
              'Rb': 37, 'Sr': 38, 'Y': 39, 'Zr': 40, 'Nb': 41, 'Mo': 42, 'Tc': 43, 
              'Ru': 44, 'Rh': 45, 'Pd': 46, 'Ag': 47, 'Cd': 48, 'In': 49, 'Sn': 50, 
              'Sb': 51, 'Te': 52, 'I': 53, 'Xe': 54, 'Cs': 55, 'Ba': 56, 'La': 57, 
              'Ce': 58, 'Pr': 59, 'Nd': 60, 'Pm': 61, 'Sm': 62, 'Eu': 63, 'Gd': 64, 
              'Tb': 65, 'Dy': 66, 'Ho': 67, 'Er': 68, 'Tm': 69, 'Yb': 70, 'Lu': 71, 
              'Hf': 72, 'Ta': 73, 'W': 74, 'Re': 75, 'Os': 76, 'Ir': 77, 'Pt': 78, 
              'Au': 79, 'Hg': 80, 'Tl': 81, 'Pb': 82, 'Bi': 83, 'Po': 84, 'At': 85, 
              'Rn': 86, 'Fr': 87, 'Ra': 88, 'Ac': 89, 'Th': 90, 'Pa': 91, 'U': 92, 
              'Np': 93, 'Pu': 94, 'Am': 95, 'Cm': 96, 'Bk': 97, 'Cf': 98, 'Es': 99, 
              'Fm': 100, 'Md': 101, 'No': 102, 'Lr': 103, 'Rf': 104, 'Db': 105, 
              'Sg': 106, 'Bh': 107, 'Hs': 108, 'Mt': 109, 'Ds': 110, 'Rg': 111, 
              'Cn': 112, 'Nh': 113, 'Fl': 114, 'Mc': 115, 'Lv': 116, 'Ts': 117, 
              'Og': 118}

    atomic_numbers_list = [mapping[element] for element in element_list]

    # Convert the list of atomic numbers to a tensor
    atomic_numbers_tensor = torch.tensor(atomic_numbers_list)

    return atomic_numbers_tensor

def map_pbc_to_binary(pbc_list):
   
    binary_list = [1 if value else 0 for value in pbc_list]
    return binary_list



def convert_to_ase(data):
    # Extract data from the input dictionary
    positions = data['pos'].numpy()
    cell = data['cell'].numpy()
    atomic_numbers = data['atomic_numbers'].numpy()
    pbc = data['pbc'].numpy().astype(bool)
    
    # Create an ASE Atoms object
    atoms = Atoms(positions=positions,
                  numbers=atomic_numbers,
                  cell=cell,
                  pbc=pbc)
    
    return atoms

# %%
class FAENet_ASEcalculator(Calculator):
    """Simulation ASE Calculator"""

    implemented_properties = ["energy", "free_energy", "forces", "stress"]

    def __init__(
        self,
        model,
        **kwargs
    ):
        Calculator.__init__(self, **kwargs)
        self.results = {}

        self.model = model
        
        
    # pylint: disable=dangerous-default-value
    def calculate(self, atoms=None, properties=None, system_changes=all_changes):
        """
        Calculate properties.
        :param atoms: ase.Atoms object
        :param properties: [str], properties to be computed, used by ASE internally
        :param system_changes: [str], system changes since last calculation, used by ASE internally
        :return:
        """
        # call to base-class to set atoms attribute
        Calculator.calculate(self, atoms)

        # prepare data
        batch=convAtomstoBatch(atoms)

        # predict + extract data
        out = self.model(batch)
        energy = out['force_regression0']["energy"].detach().cpu().item()
        forces = out['force_regression0']["force"].detach().cpu().numpy()
        stress = out['force_regression0']["stress"].squeeze(0).detach().cpu().numpy()
        # store results
        E = energy
        stress= np.array([stress[0, 0],
                                   stress[1, 1],
                                   stress[2, 2],
                                   stress[1, 2],
                                   stress[0, 2],
                                   stress[0, 1]])
        self.results = {
            "energy": E,
            # force has units eng / len:
            "forces": forces,
            "stress" : stress,
        }

# %%
def FIRE_Relax(atoms, calculator, NStep=1e4, ftol=1e-5,plot=False):
    atoms.set_calculator(calculator)
    optimizer = FIRE(atoms,logfile=None)
    trajectory = []
    energies = []
    def record_trajectory():
        trajectory.append(atoms.copy())
        energies.append(atoms.get_potential_energy())
    optimizer.attach(record_trajectory, interval=1)
    optimizer.run(fmax=ftol,steps=NStep)
    
    if(plot):
        # Plotting energy vs. optimization step
        plt.figure()
        plt.plot(energies)
        plt.xlabel('Optimization Step')
        plt.ylabel('Energy (eV)')
        plt.title('Energy vs. Optimization Step')
        plt.grid(True)
        plt.show()
    return trajectory, energies

# %%
import time
from ase.io import read
from ase.optimize import FIRE
from ase.calculators.calculator import Calculator
import matplotlib.pyplot as plt

d = data['entries'][0]['structure']['sites']
positions_list = []
atomic_numbers_list = []
calculator = FAENet_ASEcalculator(loaded_model)


for site in d:
    xyz = site['xyz']
    species = site['species'][0]  
    element = species["element"]  
    positions_list.append(xyz)
    atomic_numbers_list.append(element)
    
positions_tensor = torch.tensor(positions_list)
atomic_numbers_tensor = element_to_atomic_number(atomic_numbers_list)

# Construct the final dictionary
result_dict = {
    'pos': positions_tensor,
    'cell': torch.tensor(data['entries'][0]['structure']["lattice"]["matrix"]),  
    'atomic_numbers': atomic_numbers_tensor,
    'energy': data['entries'][0]["energy"],  
    'force': torch.zeros((len(d), 3)),  # Assuming a 3D force vector for each site
    'pbc': torch.tensor([1,1,1])  
}

# print(result_dict) 
atoms = convert_to_ase(result_dict)
batch=convAtomstoBatch(atoms)
OptimTraj,OptimEnergies=FIRE_Relax(atoms, calculator, NStep=100, ftol=1e-5,plot=False)
# Result = task.forward(batch)

# Pred_Energy_corr = Result['regression0']['corrected_total_energy'].item() * norm_factors['energy_std'] + norm_factors['energy_mean']
Pred_Energy = OptimEnergies[-1] * norm_factors['energy_std'] + norm_factors['energy_mean']

# %%
from tqdm import tqdm
# Initialize lists for storing predictions and actual values
def initialize_prediction_lists():
    return {
        'Predictions_corr_e': [],
        'Actuals_corr_e': [],
        'Predictions_e': [],
        'Actuals_e': [],
    }
    
# Function to process a data loader
def process_data_loader(data, norm_factors, task, limit=None):
    results = initialize_prediction_lists()
    # counter = 0

    for k in tqdm(range(limit)):
        d = data['entries'][k]['structure']['sites']
        positions_list = []
        atomic_numbers_list = []

        for site in d:
            xyz = site['xyz']
            species = site['species'][0]  
            element = species["element"]  
            positions_list.append(xyz)
            atomic_numbers_list.append(element)
            
        positions_tensor = torch.tensor(positions_list)
        atomic_numbers_tensor = element_to_atomic_number(atomic_numbers_list)

        # Construct the final dictionary
        result_dict = {
            'pos': positions_tensor,
            'cell': torch.tensor(data['entries'][k]['structure']["lattice"]["matrix"]),  
            'atomic_numbers': atomic_numbers_tensor,
            'energy': data['entries'][k]["energy"],  
            'force': torch.zeros((len(d), 3)),  # Assuming a 3D force vector for each site
            'pbc': torch.tensor([1,1,1])  
        }

        # print(result_dict) 
        atoms = convert_to_ase(result_dict)
        batch=convAtomstoBatch(atoms)
        OptimTraj,OptimEnergies=FIRE_Relax(atoms, calculator, NStep=10, ftol=1e-5,plot=False)

        # Result = task.forward(batch)
    

        # Pred_Energy_corr = Result['regression0']['corrected_total_energy'].item() * norm_factors['energy_std'] + norm_factors['energy_mean']
        Pred_Energy = OptimEnergies[-1] * norm_factors['energy_std'] + norm_factors['energy_mean']

        Actual_Energy_corr = result_dict['energy']
        Actual_Energy = result_dict['energy']
        results['Predictions_corr_e'].append(Pred_Energy_corr)
        results['Actuals_corr_e'].append(Actual_Energy_corr)
        
        results['Predictions_e'].append(Pred_Energy)
        results['Actuals_e'].append(Actual_Energy)

    return results

# %%
test_results = process_data_loader(data, norm_factors, task, limit=10)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:02<00:00,  3.86it/s]

# %%
data['entries']
# Out:
# [{'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -42.95538705,
#   'composition': {'Ac': 6.0, 'U': 2.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Ac 06Sep2000',
#     'PAW_PBE U 06Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Ac 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE U 06Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[6.23751047, 0.0, 0.0],
#      [0.0, 7.66636058, 0.0],
#      [0.0, 3.83318004, 6.63926316]],
#     'a': 6.23751047,
#     'b': 7.66636058,
#     'c': 7.666360578970153,
#     'alpha': 60.00000215301635,
#     'beta': 90.0,
#     'gamma': 90.0,
#     'volume': 317.4829541581899},
#    'sites': [{'species': [{'element': 'Ac', 'occu': 1}],
#      'abc': [0.24906366, 0.82950192, 0.34099616],
#      'xyz': [1.5535371869465202, 7.66636049475096, 2.2639632427894654],
#      'label': 'Ac',
#      'properties': {}},
#     {'species': [{'element': 'Ac', 'occu': 1}],
#      'abc': [0.24906366, 0.82950192, 0.82950192],
#      'xyz': [1.5535371869465202, 9.538891023407992, 5.507281538605267],
#      'label': 'Ac',
#      'properties': {}},
#     {'species': [{'element': 'Ac', 'occu': 1}],
#      'abc': [0.24906366, 0.34099616, 0.82950192],
#      'xyz': [1.5535371869465202, 5.79382972184105, 5.507281538605267],
#      'label': 'Ac',
#      'properties': {}},
#     {'species': [{'element': 'Ac', 'occu': 1}],
#      'abc': [0.75090283, 0.17036665, 0.65926669],
#      'xyz': [4.68376426407763, 3.8331800868515247, 4.377045047532141],
#      'label': 'Ac',
#      'properties': {}},
#     {'species': [{'element': 'Ac', 'occu': 1}],
#      'abc': [0.75090283, 0.17036665, 0.17036665],
#      'xyz': [4.68376426407763, 1.959138211968323, 1.131109023037614],
#      'label': 'Ac',
#      'properties': {}},
#     {'species': [{'element': 'Ac', 'occu': 1}],
#      'abc': [0.75090283, 0.65926669, 0.17036665],
#      'xyz': [4.68376426407763, 5.707222206184746, 1.131109023037614],
#      'label': 'Ac',
#      'properties': {}},
#     {'species': [{'element': 'U', 'occu': 1}],
#      'abc': [0.74725022, 0.66666667, 0.66666667],
#      'xyz': [4.660981070959803, 7.666360451665136, 4.426175462130877],
#      'label': 'U',
#      'properties': {}},
#     {'species': [{'element': 'U', 'occu': 1}],
#      'abc': [0.25285429, 0.33333333, 0.33333333],
#      'xyz': [1.5771812812594161, 3.8331801683348643, 2.2130876978691227],
#      'label': 'U',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -25.85814191,
#   'composition': {'Ac': 1.0, 'Th': 3.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Ac 06Sep2000',
#     'PAW_PBE Th 07Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Ac 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Th 07Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[5.1761226, 0.0, 0.0],
#      [0.0, 5.1761226, 0.0],
#      [-2.5880613, -2.5880613, 5.12924924]],
#     'a': 5.1761226,
#     'b': 5.1761226,
#     'c': 6.301215783573513,
#     'alpha': 114.25033093059473,
#     'beta': 114.25033093059473,
#     'gamma': 90.0,
#     'volume': 137.42410317729983},
#    'sites': [{'species': [{'element': 'Ac', 'occu': 1}],
#      'abc': [0.0, 0.0, 0.0],
#      'xyz': [0.0, 0.0, 0.0],
#      'label': 'Ac',
#      'properties': {}},
#     {'species': [{'element': 'Th', 'occu': 1}],
#      'abc': [0.25, 0.75, 0.5],
#      'xyz': [0.0, 2.5880613000000006, 2.56462462],
#      'label': 'Th',
#      'properties': {}},
#     {'species': [{'element': 'Th', 'occu': 1}],
#      'abc': [0.75, 0.25, 0.5],
#      'xyz': [2.5880613000000006, 0.0, 2.56462462],
#      'label': 'Th',
#      'properties': {}},
#     {'species': [{'element': 'Th', 'occu': 1}],
#      'abc': [0.5, 0.5, 0.0],
#      'xyz': [2.5880613, 2.5880613, 0.0],
#      'label': 'Th',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -34.93404475,
#   'composition': {'Ac': 1.0, 'U': 3.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Ac 06Sep2000',
#     'PAW_PBE U 06Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Ac 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE U 06Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[4.67145797, 0.0, 0.0],
#      [0.0, 4.67145797, 0.0],
#      [-2.33572899, -2.33572899, 4.6196856]],
#     'a': 4.67145797,
#     'b': 4.67145797,
#     'c': 5.6791508936019826,
#     'alpha': 114.28535424345318,
#     'beta': 114.28535424345318,
#     'gamma': 90.0,
#     'volume': 100.81317939235014},
#    'sites': [{'species': [{'element': 'Ac', 'occu': 1}],
#      'abc': [0.0, 0.0, 0.0],
#      'xyz': [0.0, 0.0, 0.0],
#      'label': 'Ac',
#      'properties': {}},
#     {'species': [{'element': 'U', 'occu': 1}],
#      'abc': [0.25, 0.75, 0.5],
#      'xyz': [-2.4999999848063226e-09, 2.3357289825, 2.3098428],
#      'label': 'U',
#      'properties': {}},
#     {'species': [{'element': 'U', 'occu': 1}],
#      'abc': [0.75, 0.25, 0.5],
#      'xyz': [2.3357289825, -2.4999999848063226e-09, 2.3098428],
#      'label': 'U',
#      'properties': {}},
#     {'species': [{'element': 'U', 'occu': 1}],
#      'abc': [0.5, 0.5, 0.0],
#      'xyz': [2.335728985, 2.335728985, 0.0],
#      'label': 'U',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -9.11402072,
#   'composition': {'Hg': 1.0, 'Au': 1.0, 'Ag': 2.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Au 06Sep2000',
#     'PAW_PBE Hg 06Sep2000',
#     'PAW_PBE Ag 06Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Au 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Hg 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[4.76000211, 6.591e-05, 4.66e-05],
#      [2.38005813, 4.12238161, 0.0],
#      [2.38005813, 1.3741272, 3.88661866]],
#     'a': 4.760002110684421,
#     'b': 4.760116263353794,
#     'c': 4.760116266670293,
#     'alpha': 60.000000078707444,
#     'beta': 59.99920675570918,
#     'gamma': 59.9992066712883,
#     'volume': 76.26443567936141},
#    'sites': [{'species': [{'element': 'Au', 'occu': 1}],
#      'abc': [0.24999996, 0.25000001, 0.25000001],
#      'xyz': [2.3800294497010785, 1.3741437349624517, 0.9716663538643225],
#      'label': 'Au',
#      'properties': {}},
#     {'species': [{'element': 'Hg', 'occu': 1}],
#      'abc': [0.74999782, 0.75000073, 0.75000073],
#      'xyz': [7.14008187558027, 4.122435052307747, 2.9150017821300334],
#      'label': 'Hg',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.4999998, 0.50000007, 0.50000007],
#      'xyz': [4.760058566207716, 2.7482877447424348, 1.9433329020539862],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.99999942, 1.9e-07, 1.9e-07],
#      'xyz': [4.760000253620865, 6.69542984461e-05, 4.7338430517399995e-05],
#      'label': 'Ag',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -13.22200634,
#   'composition': {'Ba': 1.0, 'La': 1.0, 'Ag': 2.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Ba_sv 06Sep2000',
#     'PAW_PBE Ag 06Sep2000',
#     'PAW_PBE La 06Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Ba_sv 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE La 06Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[5.59950663, 3.736e-05, 2.642e-05],
#      [2.79978567, 4.84937104, 0.0],
#      [2.79978567, 1.61645701, 4.57203086]],
#     'a': 5.599506630186961,
#     'b': 5.599571348016563,
#     'c': 5.599571345014529,
#     'alpha': 60.00000004794473,
#     'beta': 59.99961772758437,
#     'gamma': 59.99961776934658,
#     'volume': 124.14859854594748},
#    'sites': [{'species': [{'element': 'Ba', 'occu': 1}],
#      'abc': [0.25000032, 0.24999989, 0.24999989],
#      'xyz': [2.799770668389274, 1.6164656412708698, 1.14301381708506],
#      'label': 'Ba',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.49999723, 0.50000092, 0.50000092],
#      'xyz': [5.599528625972268, 3.232938653458319, 2.2860328461952073],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [3.68e-06, 0.99999877, 0.99999877],
#      'xyz': [5.59958505871165, 6.465820097168984, 4.572025236499267],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'La', 'occu': 1}],
#      'abc': [0.75000176, 0.74999941, 0.74999941],
#      'xyz': [8.399315028884578, 4.849395242727204, 3.429040262548292],
#      'label': 'La',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -16.31544784,
#   'composition': {'Ba': 1.0, 'Pb': 2.0, 'Ag': 2.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Pb_d 06Sep2000',
#     'PAW_PBE Ba_sv 06Sep2000',
#     'PAW_PBE Ag 06Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Pb_d 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Ba_sv 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[5.0383701, -0.03343258, -0.04884477],
#      [-0.03343258, 5.0383701, -0.04884477],
#      [-2.56093113, -2.56093113, 5.91830207]],
#     'a': 5.038717774745457,
#     'b': 5.038717774745457,
#     'c': 6.9385182782041035,
#     'alpha': 112.0170916076722,
#     'beta': 112.0170916076722,
#     'gamma': 90.75491584047583,
#     'volume': 148.9616641306419},
#    'sites': [{'species': [{'element': 'Pb', 'occu': 1}],
#      'abc': [0.66408286, 0.66408286, 0.26009142],
#      'xyz': [2.6576170082790025, 2.6576170082790025, 1.4744256402599552],
#      'label': 'Pb',
#      'properties': {}},
#     {'species': [{'element': 'Pb', 'occu': 1}],
#      'abc': [0.33591714, 0.33591714, 0.73990858],
#      'xyz': [-0.21361061827900274, -0.21361061827900274, 4.3461868897400455],
#      'label': 'Pb',
#      'properties': {}},
#     {'species': [{'element': 'Ba', 'occu': 1}],
#      'abc': [0.0, 0.0, 0.0],
#      'xyz': [0.0, 0.0, 0.0],
#      'label': 'Ba',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.70947528, 0.29052472, 0.5],
#      'xyz': [2.2844204814977505, 0.15958590850224952, 2.910306265],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.29052472, 0.70947528, 0.5],
#      'xyz': [0.15958590850224952, 2.2844204814977505, 2.910306265],
#      'label': 'Ag',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -8.4690721,
#   'composition': {'Ba': 1.0, 'Ag': 2.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Ba_sv 06Sep2000',
#     'PAW_PBE Ag 06Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Ba_sv 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[4.41798717, 0.0, 0.0],
#      [0.0, 4.91159377, 0.0],
#      [0.0, -2.45579689, 4.25356498]],
#     'a': 4.41798717,
#     'b': 4.91159377,
#     'c': 4.911593774327848,
#     'alpha': 120.00000003820212,
#     'beta': 90.0,
#     'gamma': 90.0,
#     'volume': 92.29963038368584},
#    'sites': [{'species': [{'element': 'Ba', 'occu': 1}],
#      'abc': [0.0, 0.0, 0.0],
#      'xyz': [0.0, 0.0, 0.0],
#      'label': 'Ba',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.5, 0.33333333, 0.66666667],
#      'xyz': [2.208993585, -2.7891302378790783e-08, 2.835710000845217],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.5, 0.66666667, 0.33333333],
#      'xyz': [2.208993585, 2.455796907891302, 1.4178549791547834],
#      'label': 'Ag',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -16.95203566,
#   'composition': {'Ba': 2.0, 'Ag': 4.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Ba_sv 06Sep2000',
#     'PAW_PBE Ag 06Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Ba_sv 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[4.91179963, -0.00664926, -0.00614473],
#      [2.44797218, 6.11591669, -0.34739112],
#      [2.44797251, 0.13547477, 6.12427653]],
#     'a': 4.911807974222268,
#     'b': 6.5967935653110565,
#     'c': 6.596793602874892,
#     'alpha': 83.80831725610868,
#     'beta': 68.29083535411937,
#     'gamma': 68.29083614497723,
#     'volume': 184.40069247248744},
#    'sites': [{'species': [{'element': 'Ba', 'occu': 1}],
#      'abc': [0.99854797, 0.25154441, 0.75154441],
#      'xyz': [7.360201323021934, 1.6336003564097363, 4.509145689428361],
#      'label': 'Ba',
#      'properties': {}},
#     {'species': [{'element': 'Ba', 'occu': 1}],
#      'abc': [0.00145203, 0.74845559, 0.24845559],
#      'xyz': [2.4475429969780658, 4.6111418435902625, 1.2615949905716402],
#      'label': 'Ba',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.66721064, 0.83534953, 0.8315871],
#      'xyz': [7.35781974517076, 5.217150746597996, 4.798576521126662],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.33278936, 0.16465047, 0.1684129],
#      'xyz': [2.4499245748292404, 1.0275914534020036, 0.972164158873338],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.33278961, 0.66841294, 0.66465043],
#      'xyz': [4.897898146537533, 4.17578841505043, 3.83625740695406],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.66721039, 0.33158706, 0.33534957],
#      'xyz': [4.909846173462467, 2.068953784949569, 1.9344832730459403],
#      'label': 'Ag',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -14.92107649,
#   'composition': {'Ac': 1.0, 'Bi': 1.0, 'Ag': 2.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Ac 06Sep2000',
#     'PAW_PBE Bi 08Apr2002',
#     'PAW_PBE Ag 06Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Ac 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Bi 08Apr2002'},
#     {'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[5.36511777, 0.0, 0.0],
#      [2.68255889, 4.64632829, 0.0],
#      [2.68255889, 1.5487761, 4.38060032]],
#     'a': 5.36511777,
#     'b': 5.36511777846231,
#     'c': 5.365117777815632,
#     'alpha': 59.99999995409443,
#     'beta': 59.999999986531826,
#     'gamma': 59.999999990519065,
#     'volume': 109.20003615190116},
#    'sites': [{'species': [{'element': 'Ac', 'occu': 1}],
#      'abc': [0.25, 0.25, 0.25],
#      'xyz': [2.6825588875, 1.5487760974999998, 1.09515008],
#      'label': 'Ac',
#      'properties': {}},
#     {'species': [{'element': 'Bi', 'occu': 1}],
#      'abc': [0.75, 0.75, 0.75],
#      'xyz': [8.0476766625, 4.6463282925, 3.2854502400000003],
#      'label': 'Bi',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.0, 0.0, 0.0],
#      'xyz': [0.0, 0.0, 0.0],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.5, 0.5, 0.5],
#      'xyz': [5.365117775, 3.0975521949999996, 2.19030016],
#      'label': 'Ag',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -18.87484813,
#   'composition': {'Bi': 2.0, 'Ag': 4.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Bi 08Apr2002',
#     'PAW_PBE Ag 06Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Bi 08Apr2002'},
#     {'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[5.73130937, 0.0, 0.0],
#      [2.86565469, 4.96345951, -0.0],
#      [2.86565469, 1.65448651, 4.67952268]],
#     'a': 5.73130937,
#     'b': 5.7313093713154615,
#     'c': 5.7312507297033655,
#     'alpha': 59.99966143067051,
#     'beta': 59.999661480609355,
#     'gamma': 59.99999994987493,
#     'volume': 133.11895256699214},
#    'sites': [{'species': [{'element': 'Bi', 'occu': 1}],
#      'abc': [0.3749997, 0.8749997, 0.87500089],
#      'xyz': [7.1641366925934555, 5.790702750955141, 4.094586509775185],
#      'label': 'Bi',
#      'properties': {}},
#     {'species': [{'element': 'Bi', 'occu': 1}],
#      'abc': [0.6250003, 0.1250003, 0.12499911],
#      'xyz': [4.298482057406543, 0.8272432690448591, 0.5849361702248148],
#      'label': 'Bi',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.0, 0.5, 0.0],
#      'xyz': [1.432827345, 2.481729755, 0.0],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.0, 0.5, 0.5],
#      'xyz': [2.86565469, 3.30897301, 2.33976134],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.5, 0.5, 0.5],
#      'xyz': [5.7313093749999995, 3.30897301, 2.33976134],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.0, 0.0, 0.5],
#      'xyz': [1.432827345, 0.827243255, 2.33976134],
#      'label': 'Ag',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -16.60891833,
#   'composition': {'Hf': 1.0, 'Cd': 1.0, 'Ag': 2.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Hf_pv 06Sep2000',
#     'PAW_PBE Ag 06Sep2000',
#     'PAW_PBE Cd 06Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Hf_pv 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Cd 06Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[4.76214827, 0.0, 0.0],
#      [2.38107413, 4.12414138, 0.0],
#      [2.38107413, 1.37471379, 3.88827778]],
#     'a': 4.76214827,
#     'b': 4.7621482688786125,
#     'c': 4.762148266424844,
#     'alpha': 60.000000064176376,
#     'beta': 60.000000044629466,
#     'gamma': 60.0000000616743,
#     'volume': 76.36489194142455},
#    'sites': [{'species': [{'element': 'Hf', 'occu': 1}],
#      'abc': [0.75, 0.75, 0.75],
#      'xyz': [7.143222397499999, 4.1241413775, 2.9162083350000003],
#      'label': 'Hf',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.0, 0.0, 0.0],
#      'xyz': [0.0, 0.0, 0.0],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.5, 0.5, 0.5],
#      'xyz': [4.762148265, 2.7494275850000003, 1.94413889],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Cd', 'occu': 1}],
#      'abc': [0.25, 0.25, 0.25],
#      'xyz': [2.3810741325, 1.3747137925000001, 0.972069445],
#      'label': 'Cd',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -15.64220669,
#   'composition': {'Cd': 1.0, 'I': 4.0, 'Ag': 2.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE I 08Apr2002',
#     'PAW_PBE Ag 06Sep2000',
#     'PAW_PBE Cd 06Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE I 08Apr2002'},
#     {'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Cd 06Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[6.38123056, 0.0, 0.0],
#      [0.0, 6.59057215, 0.0],
#      [0.0, 0.0, 6.59057215]],
#     'a': 6.38123056,
#     'b': 6.59057215,
#     'c': 6.59057215,
#     'alpha': 90.0,
#     'beta': 90.0,
#     'gamma': 90.0,
#     'volume': 277.1728414293031},
#    'sites': [{'species': [{'element': 'I', 'occu': 1}],
#      'abc': [0.23895417, 0.74212526, 0.74212526],
#      'xyz': [1.524821652043435, 4.891030070367509, 4.891030070367509],
#      'label': 'I',
#      'properties': {}},
#     {'species': [{'element': 'I', 'occu': 1}],
#      'abc': [0.76104583, 0.25787474, 0.74212526],
#      'xyz': [4.856408907956565, 1.699542079632491, 4.891030070367509],
#      'label': 'I',
#      'properties': {}},
#     {'species': [{'element': 'I', 'occu': 1}],
#      'abc': [0.23895417, 0.25787474, 0.25787474],
#      'xyz': [1.524821652043435, 1.699542079632491, 1.699542079632491],
#      'label': 'I',
#      'properties': {}},
#     {'species': [{'element': 'I', 'occu': 1}],
#      'abc': [0.76104583, 0.74212526, 0.25787474],
#      'xyz': [4.856408907956565, 4.891030070367509, 1.699542079632491],
#      'label': 'I',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.5, 0.0, 0.5],
#      'xyz': [3.19061528, 0.0, 3.295286075],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.5, 0.5, 0.0],
#      'xyz': [3.19061528, 3.295286075, 0.0],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Cd', 'occu': 1}],
#      'abc': [0.0, 0.0, 0.0],
#      'xyz': [0.0, 0.0, 0.0],
#      'label': 'Cd',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -15.64767218,
#   'composition': {'Cd': 1.0, 'I': 4.0, 'Ag': 2.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE I 08Apr2002',
#     'PAW_PBE Ag 06Sep2000',
#     'PAW_PBE Cd 06Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE I 08Apr2002'},
#     {'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Cd 06Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[6.47986575, 1.2e-07, 0.0],
#      [-1.2e-07, 6.47986575, 0.0],
#      [-3.23993282, -3.23993294, 6.56565479]],
#     'a': 6.479865750000001,
#     'b': 6.479865750000001,
#     'c': 8.006382014072283,
#     'alpha': 113.87037315755289,
#     'beta': 113.87037315755289,
#     'gamma': 90.0,
#     'volume': 275.68304756089327},
#    'sites': [{'species': [{'element': 'I', 'occu': 1}],
#      'abc': [0.87019848, 0.89222599, 0.25927954],
#      'xyz': [4.798720927986439, 4.941456415970613, 1.7023399537499964],
#      'label': 'I',
#      'properties': {}},
#     {'species': [{'element': 'I', 'occu': 1}],
#      'abc': [0.10777401, 0.61091893, 0.74072046],
#      'xyz': [-1.7015234859706112, 1.5587880457805756, 4.863314836250003],
#      'label': 'I',
#      'properties': {}},
#     {'species': [{'element': 'I', 'occu': 1}],
#      'abc': [0.38908107, 0.36705355, 0.25927954],
#      'xyz': [1.6811447642194235, 1.5384094514365934, 1.7023399537499964],
#      'label': 'I',
#      'properties': {}},
#     {'species': [{'element': 'I', 'occu': 1}],
#      'abc': [0.63294645, 0.12980152, 0.74072046],
#      'xyz': [1.7015234785634088, -1.5587881179864387, 4.863314836250003],
#      'label': 'I',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.25, 0.75, 0.5],
#      'xyz': [-6.249999984220267e-08, 3.2399328724999994, 3.282827395],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.5, 0.5, 0.0],
#      'xyz': [3.239932815, 3.239932935, 0.0],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Cd', 'occu': 1}],
#      'abc': [0.0, 0.0, 0.0],
#      'xyz': [0.0, 0.0, 0.0],
#      'label': 'Cd',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -9.35339113,
#   'composition': {'Cd': 1.0, 'In': 1.0, 'Ag': 2.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Cd 06Sep2000',
#     'PAW_PBE Ag 06Sep2000',
#     'PAW_PBE In_d 06Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Cd 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE In_d 06Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[4.83825915, 4.92e-05, 3.479e-05],
#      [2.41917218, 4.19012914, 0.0],
#      [2.41917218, 1.39670971, 3.95049163]],
#     'a': 4.838259150375237,
#     'b': 4.838344370377442,
#     'c': 4.838344362402732,
#     'alpha': 60.000000032250696,
#     'beta': 59.999417375680636,
#     'gamma': 59.999417434070835,
#     'volume': 80.08733755048152},
#    'sites': [{'species': [{'element': 'Cd', 'occu': 1}],
#      'abc': [0.75000181, 0.7499994, 0.7499994],
#      'xyz': [7.257458486742444, 4.190162685485742, 2.962892444767992],
#      'label': 'Cd',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.49999965, 0.50000012, 0.50000012],
#      'xyz': [4.838300642210621, 2.7934446954034424, 1.9752636840468194],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [9e-07, 0.9999997, 0.9999997],
#      'xyz': [4.838347262929927, 5.586837173992626, 3.950490444883822],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'In', 'occu': 1}],
#      'abc': [0.25000065, 0.24999978, 0.24999978],
#      'xyz': [2.4191529579326883, 1.396720783427433, 0.9876307359144549],
#      'label': 'In',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -12.48524939,
#   'composition': {'Cd': 1.0, 'Nd': 1.0, 'Ag': 2.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Nd_3 06Sep2000',
#     'PAW_PBE Ag 06Sep2000',
#     'PAW_PBE Cd 06Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Nd_3 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Cd 06Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[5.05158146, 0.00018425, 0.00013028],
#      [2.52595029, 4.37507425, 0.0],
#      [2.52595029, 1.45835808, 4.12485956]],
#     'a': 5.051581465040099,
#     'b': 5.05190058894315,
#     'c': 5.051900587578477,
#     'alpha': 60.000000067908616,
#     'beta': 59.997910317356,
#     'gamma': 59.997910278977265,
#     'volume': 91.16082292391046},
#    'sites': [{'species': [{'element': 'Nd', 'occu': 1}],
#      'abc': [0.24999991, 0.25000003, 0.25000003],
#      'xyz': [2.525870206914686, 1.4584043199863874, 1.0312475837340616],
#      'label': 'Nd',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.49999629, 0.50000124, 0.50000124],
#      'xyz': [5.051728542989503, 2.916815522772522, 2.0625000343425155],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [3.55e-06, 0.99999882, 0.99999882],
#      'xyz': [5.0519125518714985, 5.833425447203938, 4.124854693128213],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Cd', 'occu': 1}],
#      'abc': [0.74999724, 0.75000092, 0.75000092],
#      'xyz': [7.577602235383704, 4.375217801249214, 3.0937461745112222],
#      'label': 'Cd',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -12.85909474,
#   'composition': {'Cd': 1.0, 'Pt': 1.0, 'Ag': 2.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Ag 06Sep2000',
#     'PAW_PBE Pt 05Jan2001',
#     'PAW_PBE Cd 06Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Pt 05Jan2001'},
#     {'hash': None, 'titel': 'PAW_PBE Cd 06Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[4.65168359, 5.36e-06, 3.79e-06],
#      [2.32584644, 4.0284842, 0.0],
#      [2.32584644, 1.34282807, 3.79809133]],
#     'a': 4.651683590004632,
#     'b': 4.6516928759442315,
#     'c': 4.651692878841183,
#     'alpha': 59.99999996031595,
#     'beta': 59.99993397257873,
#     'gamma': 59.99993395090517,
#     'volume': 71.17325057725817},
#    'sites': [{'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.49999919, 0.50000027, 0.50000027],
#      'xyz': [4.65168572309337, 2.6856602652499713, 1.8990485854815893],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [1.3e-07, 0.99999996, 0.99999996],
#      'xyz': [4.651693298651152, 5.371312055148207, 3.7980911780768394],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Pt', 'occu': 1}],
#      'abc': [0.25000002, 0.24999999, 0.24999999],
#      'xyz': [2.325844164016743, 1.3428293537869846, 0.9495237420191626],
#      'label': 'Pt',
#      'properties': {}},
#     {'species': [{'element': 'Cd', 'occu': 1}],
#      'abc': [0.74999766, 0.75000078, 0.75000078],
#      'xyz': [6.977525095880846, 4.028492412111028, 2.848574302502369],
#      'label': 'Cd',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -16.69028611,
#   'composition': {'Cd': 1.0, 'U': 1.0, 'Ag': 2.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE U 06Sep2000',
#     'PAW_PBE Ag 06Sep2000',
#     'PAW_PBE Cd 06Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE U 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Cd 06Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[4.99704175, -0.00032554, -0.00023019],
#      [2.49823895, 4.3270768, 0.0],
#      [2.49823895, 1.44235893, 4.07960713]],
#     'a': 4.9970417659057835,
#     'b': 4.996477907926277,
#     'c': 4.996477906425154,
#     'alpha': 60.0000000632703,
#     'beta': 60.00373268297839,
#     'gamma': 60.00373270958231,
#     'volume': 88.21662227295623},
#    'sites': [{'species': [{'element': 'U', 'occu': 1}],
#      'abc': [0.24999957, 0.25000014, 0.25000014],
#      'xyz': [2.4983784632789536, 1.4422783553609844, 1.01984480624398],
#      'label': 'U',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.4999038, 0.50003207, 0.50003207],
#      'xyz': [4.996439346629904, 2.8847401521208096, 2.0398193251449377],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [9.547e-05, 0.99996818, 0.99996818],
#      'xyz': [4.996795979649095, 5.769252115475767, 4.079477294924884],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Cd', 'occu': 1}],
#      'abc': [0.74999816, 0.75000061, 0.75000061],
#      'xyz': [7.495133590794699, 4.326836162454788, 3.059535193983899],
#      'label': 'Cd',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -12.54517554,
#   'composition': {'Hg': 1.0, 'Ce': 1.0, 'Ag': 2.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Ag 06Sep2000',
#     'PAW_PBE Hg 06Sep2000',
#     'PAW_PBE Ce 28Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Hg 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Ce 28Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[5.04245252, -0.0027327, -0.00373154],
#      [-2.52358747, 4.37045566, 0.00277019],
#      [-2.52347539, -1.45416931, 4.12150785]],
#     'a': 5.042454641193554,
#     'b': 5.0467201298189375,
#     'c': 5.046718080465081,
#     'alpha': 89.9454568850903,
#     'beta': 120.03116902810977,
#     'gamma': 120.03404979130008,
#     'volume': 90.7660892380307},
#    'sites': [{'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [8.43e-06, 0.49992663, 0.50008998],
#      'xyz': [-2.5235308288281746, 1.4576916454770508, 2.0625096385706208],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.99999159, 7.334e-05, 0.99991051],
#      'xyz': [2.5189754688819086, -1.4564513241883366, 4.11740771081049],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Hg', 'occu': 1}],
#      'abc': [0.49999996, 0.75000005, 0.25000026],
#      'xyz': [-0.0023341739810756046, 2.912932908048071, 1.0305899068798121],
#      'label': 'Hg',
#      'properties': {}},
#     {'species': [{'element': 'Ce', 'occu': 1}],
#      'abc': [0.50000001, 0.24999998, 0.75000025],
#      'xyz': [-0.002277679972572777, 0.0006201315212324143, 3.089958695284244],
#      'label': 'Ce',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -11.8836438,
#   'composition': {'Ce': 1.0, 'Ag': 2.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Ag 06Sep2000',
#     'PAW_PBE Ce 28Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Ce 28Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[3.69729233, 0.0, 0.0],
#      [0.0, 3.69729233, 0.0],
#      [-1.84864617, -1.84864617, 5.07572613]],
#     'a': 3.69729233,
#     'b': 3.69729233,
#     'c': 5.709464166668893,
#     'alpha': 108.89205841215248,
#     'beta': 108.89205841215248,
#     'gamma': 90.0,
#     'volume': 69.38502683612741},
#    'sites': [{'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.68296857, 0.68296857, 0.36593715],
#      'xyz': [1.8486461446838525, 1.8486461446838525, 1.8573967541927292],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.31703143, 0.31703143, 0.63406285],
#      'xyz': [1.53161472393748e-08, 1.53161472393748e-08, 3.21832937580727],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ce', 'occu': 1}],
#      'abc': [0.0, 0.0, 0.0],
#      'xyz': [0.0, 0.0, 0.0],
#      'label': 'Ce',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -24.26280553,
#   'composition': {'Ce': 2.0, 'Ag': 4.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Ag 06Sep2000',
#     'PAW_PBE Ce 28Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Ce 28Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[4.94576488, 0.0, 0.0],
#      [2.47288244, 5.31755678, 0.47816885],
#      [2.47288244, 1.05527186, 5.23368483]],
#     'a': 4.94576488,
#     'b': 5.883893534021044,
#     'c': 5.883893537475023,
#     'alpha': 65.73179180133103,
#     'beta': 65.14773728569548,
#     'gamma': 65.14773727011718,
#     'volume': 135.14707157722148},
#    'sites': [{'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.83326632, 0.16611728, 0.16735008],
#      'xyz': [4.9457648800000005, 1.0599378987319072, 0.9552896837380144],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.16673368, 0.83388272, 0.83264992],
#      'xyz': [4.94576488, 5.3128907412680935, 4.756563996261986],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.83326632, 0.66735008, 0.66611728],
#      'xyz': [7.41864732, 4.251606763581283, 3.8053539236378704],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.16673368, 0.33264992, 0.33388272],
#      'xyz': [2.47288244, 2.121221876418717, 1.9064997563621295],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ce', 'occu': 1}],
#      'abc': [0.50051004, 0.74948996, 0.24948996],
#      'xyz': [4.94576488, 4.248735152480455, 1.6641345711490527],
#      'label': 'Ce',
#      'properties': {}},
#     {'species': [{'element': 'Ce', 'occu': 1}],
#      'abc': [0.49948996, 0.25051004, 0.75051004],
#      'xyz': [4.94576488, 2.1240934875195454, 4.047719108850947],
#      'label': 'Ce',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -9.98572181,
#   'composition': {'Ac': 1.0, 'Cs': 1.0, 'Ag': 2.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Cs_sv 08Apr2002',
#     'PAW_PBE Ac 06Sep2000',
#     'PAW_PBE Ag 06Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Cs_sv 08Apr2002'},
#     {'hash': None, 'titel': 'PAW_PBE Ac 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[5.78174675, 0.0, 0.0],
#      [2.89087337, 5.00713956, 0.0],
#      [2.89087337, 1.66904652, 4.72077645]],
#     'a': 5.78174675,
#     'b': 5.781746744254036,
#     'c': 5.781746744555132,
#     'alpha': 60.00000001794876,
#     'beta': 60.00000002606178,
#     'gamma': 60.00000002433909,
#     'volume': 136.6665390208397},
#    'sites': [{'species': [{'element': 'Cs', 'occu': 1}],
#      'abc': [0.75, 0.75, 0.75],
#      'xyz': [8.6726201175, 5.00713956, 3.5405823375],
#      'label': 'Cs',
#      'properties': {}},
#     {'species': [{'element': 'Ac', 'occu': 1}],
#      'abc': [0.25, 0.25, 0.25],
#      'xyz': [2.8908733724999998, 1.66904652, 1.1801941125],
#      'label': 'Ac',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.0, 0.0, 0.0],
#      'xyz': [0.0, 0.0, 0.0],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.5, 0.5, 0.5],
#      'xyz': [5.7817467449999995, 3.33809304, 2.360388225],
#      'label': 'Ag',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -10.5679862,
#   'composition': {'La': 1.0, 'Cs': 1.0, 'Ag': 2.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Cs_sv 08Apr2002',
#     'PAW_PBE Ag 06Sep2000',
#     'PAW_PBE La 06Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Cs_sv 08Apr2002'},
#     {'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE La 06Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[5.66341213, 9.82e-06, -0.00073332],
#      [-2.83169637, 4.91815739, 0.0095694],
#      [-0.00060442, -3.27008807, 4.62391256]],
#     'a': 5.663412177485037,
#     'b': 5.675109515956423,
#     'c': 5.663395069514895,
#     'alpha': 119.93138373225074,
#     'beta': 90.01222938064127,
#     'gamma': 119.93164218293096,
#     'volume': 128.9629497949376},
#    'sites': [{'species': [{'element': 'Cs', 'occu': 1}],
#      'abc': [0.24999971, 0.49999997, 0.74999953],
#      'xyz': [-0.00045002465454926005,
#       0.006516486893823448,
#       3.4725336166866776],
#      'label': 'Cs',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.00017852, 0.99999968, 0.99982074],
#      'xyz': [-2.8312887431753846, 1.64865394393013, 4.63265294346],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.49982056, 3.8e-07, 0.50017891],
#      'xyz': [2.83038642814599, -1.6356223093188962, 2.3124170194194225],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'La', 'occu': 1}],
#      'abc': [0.74999821, 0.49999997, 0.24999982],
#      'xyz': [2.831549755051974, 1.641564483553553, 1.1602120187212999],
#      'label': 'La',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -24.55045948,
#   'composition': {'Cs': 4.0, 'Ag': 8.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Cs_sv 08Apr2002',
#     'PAW_PBE Ag 06Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Cs_sv 08Apr2002'},
#     {'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[6.19004391, 0.0, 0.0],
#      [-3.09502195, 5.36073527, 0.0],
#      [0.0, 0.0, 10.65965311]],
#     'a': 6.19004391,
#     'b': 6.190043901783232,
#     'c': 10.65965311,
#     'alpha': 90.0,
#     'beta': 90.0,
#     'gamma': 119.99999999047039,
#     'volume': 353.7212594256014},
#    'sites': [{'species': [{'element': 'Cs', 'occu': 1}],
#      'abc': [0.66666667, 0.33333333, 0.93680322],
#      'xyz': [3.095021987616887, 1.786911738797549, 9.985997357531016],
#      'label': 'Cs',
#      'properties': {}},
#     {'species': [{'element': 'Cs', 'occu': 1}],
#      'abc': [0.33333333, 0.66666667, 0.43680322],
#      'xyz': [-2.761688611130353e-08, 3.573823531202451, 4.6561708025310145],
#      'label': 'Cs',
#      'properties': {}},
#     {'species': [{'element': 'Cs', 'occu': 1}],
#      'abc': [0.33333333, 0.66666667, 0.06319678],
#      'xyz': [-2.761688611130353e-08, 3.573823531202451, 0.6736557524689858],
#      'label': 'Cs',
#      'properties': {}},
#     {'species': [{'element': 'Cs', 'occu': 1}],
#      'abc': [0.66666667, 0.33333333, 0.56319678],
#      'xyz': [3.095021987616887, 1.786911738797549, 6.003482307468985],
#      'label': 'Cs',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.0, 0.0, 0.0],
#      'xyz': [0.0, 0.0, 0.0],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.0, 0.0, 0.5],
#      'xyz': [0.0, 0.0, 5.329826555],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.16061121, 0.83938879, 0.75],
#      'xyz': [-1.6037362872957095, 4.499741091795624, 7.9947398325000005],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.83938879, 0.67877757, 0.25],
#      'xyz': [3.0950219893441067, 3.638746859983894, 2.6649132775],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.32122243, 0.16061121, 0.25],
#      'xyz': [1.4912857262108419, 0.8609941782043767, 2.6649132775],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.67877757, 0.83938879, 0.75],
#      'xyz': [1.6037362337891587, 4.499741091795624, 7.9947398325000005],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.16061121, 0.32122243, 0.75],
#      'xyz': [-2.9344107366213734e-08, 1.7219884100161063, 7.9947398325000005],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.83938879, 0.16061121, 0.25],
#      'xyz': [4.698758247295709, 0.8609941782043767, 2.6649132775],
#      'label': 'Ag',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -13.57563931,
#   'composition': {'Tl': 1.0, 'Dy': 1.0, 'Ag': 2.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Tl_d 06Sep2000',
#     'PAW_PBE Ag 06Sep2000',
#     'PAW_PBE Dy_3 06Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Tl_d 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Dy_3 06Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[4.99402736, 0.0, 0.0],
#      [2.49701368, 4.32495456, 0.0],
#      [2.49701368, 1.44165152, 4.07760626]],
#     'a': 4.99402736,
#     'b': 4.994027359173349,
#     'c': 4.994027356234309,
#     'alpha': 59.9999999768818,
#     'beta': 59.999999975056596,
#     'gamma': 59.99999999452439,
#     'volume': 88.0719786758638},
#    'sites': [{'species': [{'element': 'Tl', 'occu': 1}],
#      'abc': [0.25, 0.25, 0.25],
#      'xyz': [2.49701368, 1.44165152, 1.019401565],
#      'label': 'Tl',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.5, 0.5, 0.5],
#      'xyz': [4.99402736, 2.88330304, 2.03880313],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Ag', 'occu': 1}],
#      'abc': [0.0, 0.0, 0.0],
#      'xyz': [0.0, 0.0, 0.0],
#      'label': 'Ag',
#      'properties': {}},
#     {'species': [{'element': 'Dy', 'occu': 1}],
#      'abc': [0.75, 0.75, 0.75],
#      'xyz': [7.491041039999999, 4.32495456, 3.0582046949999997],
#      'label': 'Dy',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -22.19436425,
#   'composition': {'Dy': 2.0, 'Ag': 4.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Ag 06Sep2000',
#     'PAW_PBE Dy_3 06Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Ag 06Sep2000'},
# ...
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Sr_sv 07Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Al 04Jan2001'},
#     {'hash': None, 'titel': 'PAW_PBE Pt 05Jan2001'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[3.95361156, 0.0, 0.0],
#      [0.0, 5.71115335, 0.0],
#      [0.0, -2.85557668, 4.94600389]],
#     'a': 3.95361156,
#     'b': 5.71115335,
#     'c': 5.711153355956654,
#     'alpha': 120.00000002341959,
#     'beta': 90.0,
#     'gamma': 90.0,
#     'volume': 111.67919453952965},
#    'sites': [{'species': [{'element': 'Sr', 'occu': 1}],
#      'abc': [0.0, 0.0, 0.0],
#      'xyz': [0.0, 0.0, 0.0],
#      'label': 'Sr',
#      'properties': {}},
#     {'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.0, 0.66666667, 0.33333333],
#      'xyz': [0.0, 2.8555767018891, 1.6486679468466536],
#      'label': 'Al',
#      'properties': {}},
#     {'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.0, 0.33333333, 0.66666667],
#      'xyz': [0.0, -3.1889100249316016e-08, 3.2973359431533464],
#      'label': 'Al',
#      'properties': {}},
#     {'species': [{'element': 'Pt', 'occu': 1}],
#      'abc': [0.5, 0.5, 0.5],
#      'xyz': [1.97680578, 1.427788335, 2.473001945],
#      'label': 'Pt',
#      'properties': {}},
#     {'species': [{'element': 'Pt', 'occu': 1}],
#      'abc': [0.5, 0.5, 0.0],
#      'xyz': [1.97680578, 2.855576675, 0.0],
#      'label': 'Pt',
#      'properties': {}},
#     {'species': [{'element': 'Pt', 'occu': 1}],
#      'abc': [0.5, 0.0, 0.5],
#      'xyz': [1.97680578, -1.42778834, 2.473001945],
#      'label': 'Pt',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -36.93113076,
#   'composition': {'Sr': 2.0, 'Al': 4.0, 'Pt': 2.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Sr_sv 07Sep2000',
#     'PAW_PBE Al 04Jan2001',
#     'PAW_PBE Pt 05Jan2001'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Sr_sv 07Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Al 04Jan2001'},
#     {'hash': None, 'titel': 'PAW_PBE Pt 05Jan2001'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[4.23829107, 0.00201438, 0.0],
#      [-2.11695405, 5.72431787, 0.0],
#      [0.0, 0.0, 7.40935879]],
#     'a': 4.238291548698429,
#     'b': 6.103221241820809,
#     'c': 7.40935879,
#     'alpha': 90.0,
#     'beta': 90.0,
#     'gamma': 110.2680541141833,
#     'volume': 179.7924600430519},
#    'sites': [{'species': [{'element': 'Sr', 'occu': 1}],
#      'abc': [0.04946701, 0.09869835, 0.75],
#      'xyz': [0.0007157149817831887, 0.5650803740001183, 5.5570190925],
#      'label': 'Sr',
#      'properties': {}},
#     {'species': [{'element': 'Sr', 'occu': 1}],
#      'abc': [0.95053299, 0.90130165, 0.25],
#      'xyz': [2.1206213050182168, 5.1612518759998816, 1.8523396975],
#      'label': 'Sr',
#      'properties': {}},
#     {'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.32168859, 0.64341022, 0.93988586],
#      'xyz': [0.0013400072775000549, 3.683732623148556, 6.963951558387709],
#      'label': 'Al',
#      'properties': {}},
#     {'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.32168859, 0.64341022, 0.56011414],
#      'xyz': [0.0013400072775000549, 3.683732623148556, 4.150086626612291],
#      'label': 'Al',
#      'properties': {}},
#     {'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.67831141, 0.35658978, 0.06011414],
#      'xyz': [2.119997012722499, 2.0425996268514446, 0.4454072316122906],
#      'label': 'Al',
#      'properties': {}},
#     {'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.67831141, 0.35658978, 0.43988586],
#      'xyz': [2.119997012722499, 2.0425996268514446, 3.2592721633877093],
#      'label': 'Al',
#      'properties': {}},
#     {'species': [{'element': 'Pt', 'occu': 1}],
#      'abc': [0.77869429, 0.55770127, 0.75],
#      'xyz': [2.1197050933503467, 3.1940279321865854, 5.5570190925],
#      'label': 'Pt',
#      'properties': {}},
#     {'species': [{'element': 'Pt', 'occu': 1}],
#      'abc': [0.22130571, 0.44229873, 0.25],
#      'xyz': [0.0016319266496532814, 2.5323043178134146, 1.8523396975],
#      'label': 'Pt',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -38.1215597,
#   'composition': {'Rh': 2.0, 'Sr': 2.0, 'Al': 4.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Sr_sv 07Sep2000',
#     'PAW_PBE Rh_pv 06Sep2000',
#     'PAW_PBE Al 04Jan2001'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Sr_sv 07Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Rh_pv 06Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Al 04Jan2001'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[4.24090942, 0.00309085, 0.0],
#      [-2.11642404, 5.71046936, 0.0],
#      [0.0, 0.0, 7.32756073]],
#     'a': 4.240910546333,
#     'b': 6.090050166344176,
#     'c': 7.32756073,
#     'alpha': 90.0,
#     'beta': 90.0,
#     'gamma': 110.29404226950565,
#     'volume': 177.5037459745288},
#    'sites': [{'species': [{'element': 'Sr', 'occu': 1}],
#      'abc': [0.04949119, 0.09832043, 0.75],
#      'xyz': [0.0017999322028726117, 0.5616087728216363, 5.4956705475],
#      'label': 'Sr',
#      'properties': {}},
#     {'species': [{'element': 'Sr', 'occu': 1}],
#      'abc': [0.95050881, 0.90167957, 0.25],
#      'xyz': [2.122685447797128, 5.151951437178364, 1.8318901825],
#      'label': 'Sr',
#      'properties': {}},
#     {'species': [{'element': 'Rh', 'occu': 1}],
#      'abc': [0.78246741, 0.56521021, 0.75],
#      'xyz': [2.122148933814554, 3.2300340755583647, 5.4956705475],
#      'label': 'Rh',
#      'properties': {}},
#     {'species': [{'element': 'Rh', 'occu': 1}],
#      'abc': [0.21753259, 0.43478979, 0.25],
#      'xyz': [0.0023364461854462615, 2.483526134441636, 1.8318901825],
#      'label': 'Rh',
#      'properties': {}},
#     {'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.31760837, 0.63558373, 0.93880855],
#      'xyz': [0.0017836425989761207, 3.6304630957099278, 6.8791766639682415],
#      'label': 'Al',
#      'properties': {}},
#     {'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.68239163, 0.36441627, 0.06119145],
#      'xyz': [2.1227017374010244, 2.0830971142900725, 0.4483840660317585],
#      'label': 'Al',
#      'properties': {}},
#     {'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.68239163, 0.36441627, 0.43880855],
#      'xyz': [2.1227017374010244, 2.0830971142900725, 3.215396298968242],
#      'label': 'Al',
#      'properties': {}},
#     {'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.31760837, 0.63558373, 0.56119145],
#      'xyz': [0.0017836425989761207, 3.6304630957099278, 4.112164431031759],
#      'label': 'Al',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -27.20914489,
#   'composition': {'Te': 4.0, 'Al': 2.0, 'Sr': 1.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Sr_sv 07Sep2000',
#     'PAW_PBE Te 08Apr2002',
#     'PAW_PBE Al 04Jan2001'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Sr_sv 07Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Te 08Apr2002'},
#     {'hash': None, 'titel': 'PAW_PBE Al 04Jan2001'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[6.95070313, -0.15505927, -4.714e-05],
#      [-3.5931269, 5.95183286, -5.936e-05],
#      [-1.67883096, -2.89847231, 6.09233437]],
#     'a': 6.952432479415166,
#     'b': 6.952328769297593,
#     'c': 6.952420671965596,
#     'alpha': 103.42154201646218,
#     'beta': 103.42204012654383,
#     'gamma': 122.39738532842738,
#     'volume': 248.63985637566415},
#    'sites': [{'species': [{'element': 'Sr', 'occu': 1}],
#      'abc': [0.5, 0.5, 0.0],
#      'xyz': [1.678788115, 2.898386795, -5.325e-05],
#      'label': 'Sr',
#      'properties': {}},
#     {'species': [{'element': 'Te', 'occu': 1}],
#      'abc': [0.84521724, 0.31748557, 0.16269697],
#      'xyz': [4.4609474633349375, 1.2869896174101145, 0.99114565274173],
#      'label': 'Te',
#      'properties': {}},
#     {'species': [{'element': 'Te', 'occu': 1}],
#      'abc': [0.68251832, 0.84521465, 0.52773171],
#      'xyz': [0.8210463945955149, 3.3951297866186216, 3.2150356891166436],
#      'label': 'Te',
#      'properties': {}},
#     {'species': [{'element': 'Te', 'occu': 1}],
#      'abc': [0.31748168, 0.15478535, 0.47226829],
#      'xyz': [0.8576988754044849, -0.49682850661862243, 2.877192180883356],
#      'label': 'Te',
#      'properties': {}},
#     {'species': [{'element': 'Te', 'occu': 1}],
#      'abc': [0.15478276, 0.68251443, 0.83730303],
#      'xyz': [-2.7822021933349372, 1.6113116625898858, 5.10108221725827],
#      'label': 'Te',
#      'properties': {}},
#     {'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.75000209, 0.25000138, 0.50000324],
#      'xyz': [3.47533427154211, -0.07757389409481164, 3.046136728982919],
#      'label': 'Al',
#      'properties': {}},
#     {'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.24999791, 0.74999862, 0.49999676],
#      'xyz': [-1.796589001542109, 2.9758751740948117, 3.0460911410170803],
#      'label': 'Al',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -9.81360466,
#   'composition': {'Al': 2.0, 'Sr': 1.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Sr_sv 07Sep2000',
#     'PAW_PBE Al 04Jan2001'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Sr_sv 07Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Al 04Jan2001'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[4.49774832, 0.0, 0.0],
#      [-2.24887416, 3.8951643, 0.0],
#      [0.0, 0.0, 4.84140217]],
#     'a': 4.49774832,
#     'b': 4.49774831571423,
#     'c': 4.84140217,
#     'alpha': 90.0,
#     'beta': 90.0,
#     'gamma': 120.0000000315207,
#     'volume': 84.81879371582113},
#    'sites': [{'species': [{'element': 'Sr', 'occu': 1}],
#      'abc': [0.0, 0.0, 0.0],
#      'xyz': [0.0, 0.0, 0.0],
#      'label': 'Sr',
#      'properties': {}},
#     {'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.66666667, 0.33333333, 0.5],
#      'xyz': [2.248874182488742, 1.2983880870161189, 2.420701085],
#      'label': 'Al',
#      'properties': {}},
#     {'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.33333333, 0.66666667, 0.5],
#      'xyz': [-2.2488741757697994e-08, 2.596776212983881, 2.420701085],
#      'label': 'Al',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -19.66892095,
#   'composition': {'Al': 4.0, 'Sr': 2.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Sr_sv 07Sep2000',
#     'PAW_PBE Al 04Jan2001'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Sr_sv 07Sep2000'},
#     {'hash': None, 'titel': 'PAW_PBE Al 04Jan2001'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[4.75098036, 0.0, 0.0],
#      [-2.37549018, 4.11446969, 0.0],
#      [0.0, 0.0, 7.85682957]],
#     'a': 4.75098036,
#     'b': 4.750980364641084,
#     'c': 7.85682957,
#     'alpha': 90.0,
#     'beta': 90.0,
#     'gamma': 119.99999996768545,
#     'volume': 153.5834556359786},
#    'sites': [{'species': [{'element': 'Sr', 'occu': 1}],
#      'abc': [0.0, 0.0, 0.25],
#      'xyz': [0.0, 0.0, 1.9642073925],
#      'label': 'Sr',
#      'properties': {}},
#     {'species': [{'element': 'Sr', 'occu': 1}],
#      'abc': [0.0, 0.0, 0.75],
#      'xyz': [0.0, 0.0, 5.8926221775],
#      'label': 'Sr',
#      'properties': {}},
#     {'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.66666667, 0.33333333, 0.036785],
#      'xyz': [2.3754902037549015, 1.3714898829517677, 0.28901347573245],
#      'label': 'Al',
#      'properties': {}},
#     {'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.33333333, 0.66666667, 0.536785],
#      'xyz': [-2.3754901823380692e-08, 2.7429798070482323, 4.21742826073245],
#      'label': 'Al',
#      'properties': {}},
#     {'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.66666667, 0.33333333, 0.463215],
#      'xyz': [2.3754902037549015, 1.3714898829517677, 3.63940130926755],
#      'label': 'Al',
#      'properties': {}},
#     {'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.33333333, 0.66666667, 0.963215],
#      'xyz': [-2.3754901823380692e-08, 2.7429798070482323, 7.567816094267551],
#      'label': 'Al',
#      'properties': {}}]}},
#  {'@module': 'pymatgen.entries.computed_entries',
#   '@class': 'ComputedStructureEntry',
#   'energy': -88.3513573,
#   'composition': {'Ta': 6.0, 'Al': 4.0},
#   'correction': 0.0,
#   'parameters': {'potcar_symbols': ['PAW_PBE Al 04Jan2001',
#     'PAW_PBE Ta_pv 07Sep2000'],
#    'is_hubbard': False,
#    'hubbards': {},
#    'run_type': 'None or LDA',
#    'potcar_spec': [{'hash': None, 'titel': 'PAW_PBE Al 04Jan2001'},
#     {'hash': None, 'titel': 'PAW_PBE Ta_pv 07Sep2000'}]},
#   'data': {},
#   'entry_id': None,
#   'structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[3.49100545, 0.0, 0.0],
#      [0.0, 6.97603937, 0.0],
#      [0.0, 0.0, 6.97603937]],
#     'a': 3.49100545,
#     'b': 6.97603937,
#     'c': 6.97603937,
#     'alpha': 90.0,
#     'beta': 90.0,
#     'gamma': 90.0,
#     'volume': 169.89021761857168},
#    'sites': [{'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.0, 0.6257029, 0.1257029],
#      'xyz': [0.0, 4.3649280643231725, 0.876908379323173],
#      'label': 'Al',
#      'properties': {}},
#     {'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.0, 0.8742971, 0.6257029],
#      'xyz': [0.0, 6.099130990676827, 4.3649280643231725],
#      'label': 'Al',
#      'properties': {}},
#     {'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.0, 0.1257029, 0.3742971],
#      'xyz': [0.0, 0.876908379323173, 2.6111113056768267],
#      'label': 'Al',
#      'properties': {}},
#     {'species': [{'element': 'Al', 'occu': 1}],
#      'abc': [0.0, 0.3742971, 0.8742971],
#      'xyz': [0.0, 2.6111113056768267, 6.099130990676827],
#      'label': 'Al',
#      'properties': {}},
#     {'species': [{'element': 'Ta', 'occu': 1}],
#      'abc': [0.5, 0.67452329, 0.82547671],
#      'xyz': [1.745502725, 4.705501027021927, 5.758558027978072],
#      'label': 'Ta',
#      'properties': {}},
#     {'species': [{'element': 'Ta', 'occu': 1}],
#      'abc': [0.5, 0.82547671, 0.32547671],
#      'xyz': [1.745502725, 5.758558027978072, 2.2705383429780728],
#      'label': 'Ta',
#      'properties': {}},
#     {'species': [{'element': 'Ta', 'occu': 1}],
#      'abc': [0.5, 0.32547671, 0.17452329],
#      'xyz': [1.745502725, 2.2705383429780728, 1.2174813420219273],
#      'label': 'Ta',
#      'properties': {}},
#     {'species': [{'element': 'Ta', 'occu': 1}],
#      'abc': [0.5, 0.17452329, 0.67452329],
#      'xyz': [1.745502725, 1.2174813420219273, 4.705501027021927],
#      'label': 'Ta',
#      'properties': {}},
#     {'species': [{'element': 'Ta', 'occu': 1}],
#      'abc': [0.0, 0.5, 0.5],
#      'xyz': [0.0, 3.488019685, 3.488019685],
#      'label': 'Ta',
#      'properties': {}},
#     {'species': [{'element': 'Ta', 'occu': 1}],
#      'abc': [0.0, 0.0, 0.0],
#      'xyz': [0.0, 0.0, 0.0],
#      'label': 'Ta',
#      'properties': {}}]}},
#  ...]

# %%
# Function to plot R² score
def plot_r2_score(actual, pred, title="Title", suffix="500k_Faenet"):
    # save_dir = '/home/civil/phd/cez218288/scratch/Simulation/plots/'

    # Calculate R² score
    r2 = r2_score(actual, pred)

    # Create the scatter plot
    plt.figure(figsize=(6, 6))
    plt.scatter(actual, pred, label='Test', color='green')
    plt.xlabel("Actual", fontsize=20, fontweight='bold')
    plt.ylabel("Predicted", fontsize=20, fontweight='bold')
    plt.xticks(rotation=90, fontsize=20, fontweight='bold')
    plt.yticks(fontsize=20, fontweight='bold')
    min_val = min(min(actual), min(pred))
    max_val = max(max(actual), max(pred))
    plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--')
    plt.title(title, fontsize=20, fontweight='bold')

    # Annotate the R² score on the plot
    plt.text(0.05, 0.95, f'R² = {r2:.5f}', transform=plt.gca().transAxes, fontsize=12, fontweight='bold', verticalalignment='top', color='green')

    # Save the plot
    # filename = f"{title.replace(' ', '_')}_{suffix}.png"
    # plt.savefig(f'{save_dir}{filename}', bbox_inches='tight')
    plt.show()
    plt.clf()

# Plot and save the results for test data
plot_r2_score(test_results['Actuals_corr_e'], test_results['Predictions_corr_e'], "Corrected Total Energy", "10k_Faenet_MP_WBM")
plot_r2_score(test_results['Actuals_e'], test_results['Predictions_e'], "Energy", "10k_Faenet_MP_WBM")
# plot_r2_score(test_results['Actuals_Fx'], test_results['Predictions_Fx'], "Fx", "500k_Faenet_trail")
# plot_r2_score(test_results['Actuals_Fy'], test_results['Predictions_Fy'], "Fy", "500k_Faenet_trail")
# plot_r2_score(test_results['Actuals_Fz'], test_results['Predictions_Fz'], "Fz", "500k_Faenet_trail")

# %%
print(atoms)
# Out:
# Atoms(symbols='Ac6U2', pbc=True, cell=[[6.237510681152344, 0.0, 0.0], [0.0, 7.666360378265381, 0.0], [0.0, 3.8331799507141113, 6.639263153076172]])

# %%
batch=convAtomstoBatch(atoms)

# %%
Result = task.forward(batch)

Pred_Energy_corr = Result['regression0']['corrected_total_energy'].item() * norm_factors['energy_std'] + norm_factors['energy_mean']
Pred_Energy = Result['force_regression0']['energy'].item() * norm_factors['energy_std'] + norm_factors['energy_mean']

# %%
Pred_Energy_corr
# Out:
# 5.368939604459484

# %%
print(Result)
# Out:
# {'regression0': {'corrected_total_energy': tensor([[1.0350]], grad_fn=<MeanBackward1>)}, 'force_regression0': {'force': tensor([[ 5.5071e-04,  6.0410e-04,  1.8533e-03],
#         [-1.6596e-05,  2.8100e-03, -1.8435e-03],
#         [-5.8506e-05, -8.3388e-04, -1.4833e-03],
#         [-5.5246e-04,  2.9204e-04,  1.4140e-04],
#         [-6.9396e-05, -1.6704e-03,  3.6612e-03],
#         [ 9.6483e-06,  2.5333e-03,  3.1701e-03],
#         [-9.7421e-05, -1.8095e-03, -1.4890e-03],
#         [ 2.3402e-04, -1.9257e-03, -4.0101e-03]], grad_fn=<SumBackward1>), 'energy': tensor([[2.5692]], grad_fn=<SumBackward1>), 'node_energies': tensor([[[0.4722]],
#
#         [[0.3262]],
#
#         [[0.3274]],
#
#         [[0.4687]],
#
#         [[0.3318]],
#
#         [[0.3307]],
#
#         [[0.1546]],
#
#         [[0.1577]]], grad_fn=<ViewBackward0>)}}

# %%
# Load Data
dm = MatSciMLDataModule(
    "MaterialsProjectDataset",
    train_path="/home/m3rg2000/matsciml/Scale_new_lmdb/test_new",#TRAIN_PATH,
    # val_split=VAL_PATH,
    # test_split=VAL_PATH,
    dset_kwargs={
        "transforms": [
            PeriodicPropertiesTransform(cutoff_radius=6.0, adaptive_cutoff=True),
            PointCloudToGraphTransform(
                "pyg",
                node_keys=["pos", "atomic_numbers"],
            ),
            FrameAveraging(frame_averaging="3D", fa_method="stochastic"),
        ],
    },
    batch_size=1,
)

dm.setup()
train_loader = dm.train_dataloader()
dataset_iter = iter(train_loader)
batch = next(dataset_iter)

# %%
from tqdm import tqdm
# Initialize lists for storing predictions and actual values
def initialize_prediction_lists():
    return {
        'Predictions_corr_e': [],
        'Actuals_corr_e': [],
        'Predictions_e': [],
        'Actuals_e': [],
        'Predictions_Fx': [],
        'Actuals_Fx': [],
        'Predictions_Fy': [],
        'Actuals_Fy': [],
        'Predictions_Fz': [],
        'Actuals_Fz': []
    }

# Function to process a data loader
def process_data_loader(data_loader, norm_factors, task, limit=None):
    results = initialize_prediction_lists()
    counter = 0

    for batch in tqdm(data_loader):
        Result = task.forward(batch)

        Pred_Energy_corr = Result['regression0']['corrected_total_energy'].item() * norm_factors['energy_std'] + norm_factors['energy_mean']
        Pred_Energy = Result['force_regression0']['energy'].item() * norm_factors['energy_std'] + norm_factors['energy_mean']

        Pred_Forces = Result['force_regression0']['force']* norm_factors['energy_std'] 
        Actual_Energy_corr = batch['targets']['energy'].item()
        Actual_Energy = batch['targets']['corrected_total_energy'].item()
        
        Actual_Forces = batch['targets']['force']

        results['Predictions_corr_e'].append(Pred_Energy_corr)
        results['Actuals_corr_e'].append(Actual_Energy_corr)
        
        results['Predictions_e'].append(Pred_Energy)
        results['Actuals_e'].append(Actual_Energy)
        
        results['Predictions_Fx'] += Pred_Forces[:, 0].reshape(-1).detach().numpy().tolist()
        results['Actuals_Fx'] += Actual_Forces[:, 0].reshape(-1).detach().numpy().tolist()

        results['Predictions_Fy'] += Pred_Forces[:, 1].reshape(-1).detach().numpy().tolist()
        results['Actuals_Fy'] += Actual_Forces[:, 1].reshape(-1).detach().numpy().tolist()

        results['Predictions_Fz'] += Pred_Forces[:, 2].reshape(-1).detach().numpy().tolist()
        results['Actuals_Fz'] += Actual_Forces[:, 2].reshape(-1).detach().numpy().tolist()

        counter += 1
        if limit and counter >= 10000:
            break

    return results
test_results = process_data_loader(train_loader, norm_factors, task, limit=10000)
# Out:
#   0%|          | 0/196517 [00:00<?, ?it/s]
# /home/m3rg2000/miniconda3/envs/matsciml/lib/python3.9/site-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/conda/conda-bld/pytorch_1704987290837/work/aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#   0%|          | 616/196517 [00:42<3:43:20, 14.62it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 54
#      51             break
#      53     return results
# ---> 54 test_results = process_data_loader(train_loader, norm_factors, task, limit=100000)
#
# Cell In[26], line 47, in process_data_loader(data_loader, norm_factors, task, limit)
#      44 results['Actuals_Fy'] += Actual_Forces[:, 1].reshape(-1).detach().numpy().tolist()
#      46 results['Predictions_Fz'] += Pred_Forces[:, 2].reshape(-1).detach().numpy().tolist()
# ---> 47 results['Actuals_Fz'] += Actual_Forces[:, 2].reshape(-1).detach().numpy().tolist()
#      49 counter += 1
#      50 if limit and counter >= 10000:
#
# KeyboardInterrupt:

# %%
def plot_r2_score(actual,pred,title="Title"):

    # Calculate R² score
    r2 = r2_score(actual, pred)

    # Create the scatter plot
    plt.scatter(actual, pred)
    plt.xlabel("Actual")
    plt.ylabel("Predicted")

    # Plot the 45-degree line
    min_val = min(min(actual), min(pred))
    max_val = max(max(actual), max(pred))
    plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--')
    plt.title(title)
    # Annotate the R² score on the plot
    plt.text(0.05, 0.95, f'R² = {r2:.5f}', transform=plt.gca().transAxes, fontsize=12, verticalalignment='top')

    # Show the plot
    plt.show()

# %%
plot_r2_score(Actuals_e,Predictions_e,"Energy")
plot_r2_score(Actuals_corr_e,Predictions_corr_e,"Corrected Total Energy")
plot_r2_score(Actuals_Fx,Predictions_Fx,"Fx")
plot_r2_score(Actuals_Fy,Predictions_Fy,"Fy")
plot_r2_score(Actuals_Fz,Predictions_Fz,"Fz")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 plot_r2_score(Actuals_e,Predictions_e,"Energy")
#       2 plot_r2_score(Actuals_corr_e,Predictions_corr_e,"Corrected Total Energy")
#       3 plot_r2_score(Actuals_Fx,Predictions_Fx,"Fx")
#
# NameError: name 'Actuals_e' is not defined

# %%
# Calculate R² score
r2 = r2_score(Actuals_e, Predictions_e)

# Create the scatter plot
plt.scatter(Actuals_e, Predictions_e)
plt.xlabel("Actual")
plt.ylabel("Predicted")

# Plot the 45-degree line
min_val = min(min(Actuals_e), min(Predictions_e))
max_val = max(max(Actuals_e), max(Predictions_e))
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--')
plt.title("Force Regression: ")
# Annotate the R² score on the plot
plt.text(0.05, 0.95, f'R² = {r2:.5f}', transform=plt.gca().transAxes, fontsize=12, verticalalignment='top')

# Show the plot
plt.show()

# %%
# Calculate R² score
r2 = r2_score(Actuals_e, Predictions_e)

# Create the scatter plot
plt.scatter(Actuals_e, Predictions_e)
plt.xlabel("Actual")
plt.ylabel("Predicted")

# Plot the 45-degree line
min_val = min(min(Actuals_e), min(Predictions_e))
max_val = max(max(Actuals_e), max(Predictions_e))
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--')

# Annotate the R² score on the plot
plt.text(0.05, 0.95, f'R² = {r2:.5f}', transform=plt.gca().transAxes, fontsize=12, verticalalignment='top')

# Show the plot
plt.show()
